# %%
# We will be using these PDF loaders but you can check out other loaded documents
from langchain_community.document_loaders import PyMuPDFLoader
from langchain_community.document_loaders import UnstructuredPDFLoader

# This is the name of the report which should be in the directory
# You can download the precise PDF I am using from here https://www.pc.gov.pk/uploads/archives/PSDP_2023-24.pdf
name = 'Att 5. Air Quality Assessment 4567 Old Northern Road Maroota.pdf'

# This loader uses PyMuPDF
loader_py = PyMuPDFLoader(name)

#This loader uses Unstructured
loader_un = UnstructuredPDFLoader(name)

# Storing the loaded documents as langChain Document object
pages_py = loader_py.load()

# pages_un = loader_un.load()

# %%
# text splitter
from langchain.text_splitter import CharacterTextSplitter
text_splitter = CharacterTextSplitter(
    # shows how to seperate
    separator="\n",
    # Shows the document token length
    chunk_size=1000,
    # How much overlap should exist between documents
    chunk_overlap=150,
    # How to measure length
    length_function=len
)

# Applying the splitter
docs = text_splitter.split_documents(pages_py)

docs
# Out:
# [Document(metadata={'producer': 'Microsoft® Word 2013', 'creator': 'Microsoft® Word 2013', 'creationdate': '2017-09-29T07:53:36+10:00', 'source': 'Att 5. Air Quality Assessment 4567 Old Northern Road Maroota.pdf', 'file_path': 'Att 5. Air Quality Assessment 4567 Old Northern Road Maroota.pdf', 'total_pages': 63, 'format': 'PDF 1.5', 'title': 'Air Quality Assessment – Lot 1 DP 590937 AT 4567 Old Northern Road, Maroota Proposed Sand Quarry', 'author': 'Deanna Tuxford', 'subject': 'PF Formation', 'keywords': '', 'moddate': '2018-05-28T14:58:20+10:00', 'trapped': '', 'modDate': "D:20180528145820+10'00'", 'creationDate': "D:20170929075336+10'00'", 'page': 0}, page_content='Report \n \nAir Quality Assessment – Lot 1 DP 590937 AT 4567 Old Northern \nRoad, Maroota Proposed Sand Quarry\nPF Formation \nJob ID. 20477 \n28 September 2017 \nATTACHMENT 5'),
#  Document(metadata={'producer': 'Microsoft® Word 2013', 'creator': 'Microsoft® Word 2013', 'creationdate': '2017-09-29T07:53:36+10:00', 'source': 'Att 5. Air Quality Assessment 4567 Old Northern Road Maroota.pdf', 'file_path': 'Att 5. Air Quality Assessment 4567 Old Northern Road Maroota.pdf', 'total_pages': 63, 'format': 'PDF 1.5', 'title': 'Air Quality Assessment – Lot 1 DP 590937 AT 4567 Old Northern Road, Maroota Proposed Sand Quarry', 'author': 'Deanna Tuxford', 'subject': 'PF Formation', 'keywords': '', 'moddate': '2018-05-28T14:58:20+10:00', 'trapped': '', 'modDate': "D:20180528145820+10'00'", 'creationDate': "D:20170929075336+10'00'", 'page': 1}, page_content='20477B PF Formation Maroota Air Quality_R1.docx \nii \nJob ID 20477 | AQU-NW-005-20477 \nPROJECT NAME: \nAir Quality Assessment – Lot 1 DP 590937 AT 4567 Old \nNorthern Road, Maroota Proposed Sand Quarry \nJOB ID: \n20477 \nDOCUMENT CONTROL NUMBER \nAQU-NW-005-20477 \nPREPARED FOR: \nPF Formation \nAPPROVED FOR RELEASE BY: \nJudith Cox \nDISCLAIMER & COPYRIGHT: \nThis report is subject to the copyright statement \nlocated at www.pacific-environment.com © Pacific \nEnvironment Operations Pty Ltd ABN 86 127 101 642 \n \nDOCUMENT CONTROL \nVERSION \nDATE \nPREPARED BY \nREVIEWED BY \nD1 \n23.06.16 \nAngelo Rouggos \nJudith Cox \nD2 \n30.06.16 \nAngelo Rouggos/Judith Cox \nJudith Cox/Jane Barnett \nD3 \n05.07.16 \nAngelo Rouggos/Judith Cox \nJudith Cox/Jane Barnett \nD4 \n22.08.16 \nAngelo Rouggos/Judith Cox \nJudith Cox/Li Fitzmaurice \nD5 \n25.09.17 \nRuss Francis/Judith Cox \nJudith Cox \nR1 \n28.09.17 \nRuss Francis/Judith Cox \nJudith Cox \n \nPacific Environment Operations Pty Ltd: ABN 86 127 101 642 \nBRISBANE'),
#  Document(metadata={'producer': 'Microsoft® Word 2013', 'creator': 'Microsoft® Word 2013', 'creationdate': '2017-09-29T07:53:36+10:00', 'source': 'Att 5. Air Quality Assessment 4567 Old Northern Road Maroota.pdf', 'file_path': 'Att 5. Air Quality Assessment 4567 Old Northern Road Maroota.pdf', 'total_pages': 63, 'format': 'PDF 1.5', 'title': 'Air Quality Assessment – Lot 1 DP 590937 AT 4567 Old Northern Road, Maroota Proposed Sand Quarry', 'author': 'Deanna Tuxford', 'subject': 'PF Formation', 'keywords': '', 'moddate': '2018-05-28T14:58:20+10:00', 'trapped': '', 'modDate': "D:20180528145820+10'00'", 'creationDate': "D:20170929075336+10'00'", 'page': 1}, page_content='Judith Cox \nR1 \n28.09.17 \nRuss Francis/Judith Cox \nJudith Cox \n \nPacific Environment Operations Pty Ltd: ABN 86 127 101 642 \nBRISBANE  \nLevel 19, 240 Queen Street \nBrisbane QLD 4000  \nPh: +61 7 3004 6400  \nFax: +61 7 3844 5858 \nADELAIDE  \n35 Edward Street, Norwood  SA  5067 \nPO Box 3187, Norwood  SA  5067 \nPh: +61 8 8332 0960 \nFax: +61 7 3844 5858 \n \nSYDNEY  \nSuite 1, Level 1, 146 Arthur Street \nNorth Sydney, NSW  2060 \nPh: +61 2 9870 0900 \nFax: +61 2 9870 0999 \nMELBOURNE  \nLevel 17, 31 Queen Street \nMelbourne  Vic  3000 \nPh: +61 3 9036 2637 \nFax: +61 2 9870 0999 \nPERTH  \nLevel 1, Suite 3 \n34 Queen Street, Perth  WA  6000 \nPh: +61 8 9481 4961 \nFax: +61 2 9870 0999'),
#  Document(metadata={'producer': 'Microsoft® Word 2013', 'creator': 'Microsoft® Word 2013', 'creationdate': '2017-09-29T07:53:36+10:00', 'source': 'Att 5. Air Quality Assessment 4567 Old Northern Road Maroota.pdf', 'file_path': 'Att 5. Air Quality Assessment 4567 Old Northern Road Maroota.pdf', 'total_pages': 63, 'format': 'PDF 1.5', 'title': 'Air Quality Assessment – Lot 1 DP 590937 AT 4567 Old Northern Road, Maroota Proposed Sand Quarry', 'author': 'Deanna Tuxford', 'subject': 'PF Formation', 'keywords': '', 'moddate': '2018-05-28T14:58:20+10:00', 'trapped': '', 'modDate': "D:20180528145820+10'00'", 'creationDate': "D:20170929075336+10'00'", 'page': 2}, page_content='20477B PF Formation Maroota Air Quality_R1.docx \niii \nJob ID 20477 | AQU-NW-005-20477 \nDISCLAIMER \nPacific Environment acts in all professional matters as a faithful advisor to the Client and exercises all \nreasonable skill and care in the provision of its professional services. \nReports are commissioned by and prepared for the exclusive use of the Client. They are subject to and \nissued in accordance with the agreement between the Client and Pacific Environment. Pacific \nEnvironment is not responsible for any liability and accepts no responsibility whatsoever arising from the \nmisapplication or misinterpretation by third parties of the contents of its reports. \nExcept where expressly stated, Pacific Environment does not attempt to verify the accuracy, validity or \ncomprehensiveness of any information supplied to Pacific Environment for its reports. \nWhere site inspections, testing or fieldwork have taken place, the report is based on the information'),
#  Document(metadata={'producer': 'Microsoft® Word 2013', 'creator': 'Microsoft® Word 2013', 'creationdate': '2017-09-29T07:53:36+10:00', 'source': 'Att 5. Air Quality Assessment 4567 Old Northern Road Maroota.pdf', 'file_path': 'Att 5. Air Quality Assessment 4567 Old Northern Road Maroota.pdf', 'total_pages': 63, 'format': 'PDF 1.5', 'title': 'Air Quality Assessment – Lot 1 DP 590937 AT 4567 Old Northern Road, Maroota Proposed Sand Quarry', 'author': 'Deanna Tuxford', 'subject': 'PF Formation', 'keywords': '', 'moddate': '2018-05-28T14:58:20+10:00', 'trapped': '', 'modDate': "D:20180528145820+10'00'", 'creationDate': "D:20170929075336+10'00'", 'page': 2}, page_content='Where site inspections, testing or fieldwork have taken place, the report is based on the information \nmade available by the client or their nominees during the visit, visual observations and any subsequent \ndiscussions with regulatory authorities. The validity and comprehensiveness of supplied information has \nnot been independently verified and, for the purposes of this report, it is assumed that the information \nprovided to Pacific Environment is both complete and accurate. It is further assumed that normal \nactivities were being undertaken at the site on the day of the site visit(s), unless explicitly stated \notherwise.'),
#  Document(metadata={'producer': 'Microsoft® Word 2013', 'creator': 'Microsoft® Word 2013', 'creationdate': '2017-09-29T07:53:36+10:00', 'source': 'Att 5. Air Quality Assessment 4567 Old Northern Road Maroota.pdf', 'file_path': 'Att 5. Air Quality Assessment 4567 Old Northern Road Maroota.pdf', 'total_pages': 63, 'format': 'PDF 1.5', 'title': 'Air Quality Assessment – Lot 1 DP 590937 AT 4567 Old Northern Road, Maroota Proposed Sand Quarry', 'author': 'Deanna Tuxford', 'subject': 'PF Formation', 'keywords': '', 'moddate': '2018-05-28T14:58:20+10:00', 'trapped': '', 'modDate': "D:20180528145820+10'00'", 'creationDate': "D:20170929075336+10'00'", 'page': 3}, page_content='20477B PF Formation Maroota Air Quality_R1.docx \niv \nJob ID 20477 | AQU-NW-005-20477 \nEXECUTIVE SUMMARY \nPacific Environment has prepared this air quality and greenhouse gas assessment for PF Formation (the \nProponent). It assesses the air quality impacts associated with the proposed Maroota sand quarry at \nLot 1 DP 590937 at 4567 Old Northern Road, Maroota (the proposal).  \nThe assessment was prepared in accordance with the NSW EPA “Approved Methods for the Modelling \nand Assessment of Air Pollutants in NSW” (Approved Methods) (NSW EPA, 2016). \nThe surrounding land use is primarily rural and bushland, although there is significant sand extraction \nactivity in the area, both by PF Formation and other companies. \nAERMOD was chosen as the most suitable model due to the source types, location of nearest receivers \nand nature of local topography. AERMOD is the US-EPA’s recommended steady-state plume dispersion'),
#  Document(metadata={'producer': 'Microsoft® Word 2013', 'creator': 'Microsoft® Word 2013', 'creationdate': '2017-09-29T07:53:36+10:00', 'source': 'Att 5. Air Quality Assessment 4567 Old Northern Road Maroota.pdf', 'file_path': 'Att 5. Air Quality Assessment 4567 Old Northern Road Maroota.pdf', 'total_pages': 63, 'format': 'PDF 1.5', 'title': 'Air Quality Assessment – Lot 1 DP 590937 AT 4567 Old Northern Road, Maroota Proposed Sand Quarry', 'author': 'Deanna Tuxford', 'subject': 'PF Formation', 'keywords': '', 'moddate': '2018-05-28T14:58:20+10:00', 'trapped': '', 'modDate': "D:20180528145820+10'00'", 'creationDate': "D:20170929075336+10'00'", 'page': 3}, page_content='and nature of local topography. AERMOD is the US-EPA’s recommended steady-state plume dispersion \nmodel for regulatory purposes and is now commonly applied to air quality assessments of this nature in \nNSW and accepted by the NSW EPA. \nThe results of the dispersion modelling indicate that the predicted annual average PM2.5. PM10, TSP and \ndust deposition at the closest sensitive receptors are all predicted to comply with the relevant \nassessment criteria, even when considering the existing air quality. \nWhen considering the maximum predicted 24-hour average concentrations, only the receptor (R8) is \npredicted to experience one additional exceedance of the relevant criterion for PM10 criteria on a \ncumulative basis, that is, when existing background concentrations are included. It is expected that the \nmanagement practices at the site would minimise the potential for the additional predicted \nexceedance at R8.'),
#  Document(metadata={'producer': 'Microsoft® Word 2013', 'creator': 'Microsoft® Word 2013', 'creationdate': '2017-09-29T07:53:36+10:00', 'source': 'Att 5. Air Quality Assessment 4567 Old Northern Road Maroota.pdf', 'file_path': 'Att 5. Air Quality Assessment 4567 Old Northern Road Maroota.pdf', 'total_pages': 63, 'format': 'PDF 1.5', 'title': 'Air Quality Assessment – Lot 1 DP 590937 AT 4567 Old Northern Road, Maroota Proposed Sand Quarry', 'author': 'Deanna Tuxford', 'subject': 'PF Formation', 'keywords': '', 'moddate': '2018-05-28T14:58:20+10:00', 'trapped': '', 'modDate': "D:20180528145820+10'00'", 'creationDate': "D:20170929075336+10'00'", 'page': 3}, page_content='management practices at the site would minimise the potential for the additional predicted \nexceedance at R8. \nWhen taking account of the conservative nature of the assessment (see Section 8), the limitations of \ndispersion modelling (see Section 6 and Section 10.2.1), and the implementation of appropriate \nmanagement measures (see Section 7), it is considered that any exceedances are unlikely to occur in \npractice.'),
#  Document(metadata={'producer': 'Microsoft® Word 2013', 'creator': 'Microsoft® Word 2013', 'creationdate': '2017-09-29T07:53:36+10:00', 'source': 'Att 5. Air Quality Assessment 4567 Old Northern Road Maroota.pdf', 'file_path': 'Att 5. Air Quality Assessment 4567 Old Northern Road Maroota.pdf', 'total_pages': 63, 'format': 'PDF 1.5', 'title': 'Air Quality Assessment – Lot 1 DP 590937 AT 4567 Old Northern Road, Maroota Proposed Sand Quarry', 'author': 'Deanna Tuxford', 'subject': 'PF Formation', 'keywords': '', 'moddate': '2018-05-28T14:58:20+10:00', 'trapped': '', 'modDate': "D:20180528145820+10'00'", 'creationDate': "D:20170929075336+10'00'", 'page': 4}, page_content='20477B PF Formation Maroota Air Quality_R1.docx \nv \nJob ID 20477 | AQU-NW-005-20477 \nCONTENTS \n1 INTRODUCTION \n1 \n2 PROPOSAL DESCRIPTION \n1 \n3 LOCAL SETTING \n2 \n4.1 Impact Assessment Criteria \n4 \n4.2 Crystalline Silica \n5 \n5 EXISTING ENVIRONMENT \n7 \n5.1 Local Climatic Conditions \n7 \n5.2 Local Meteorology \n8 \n Wind Speed and Direction \n8 \n Suitability of Meteorology \n8 \n Atmospheric Stability \n10 \n5.3 Existing Air Quality \n13 \n PM10 and PM2.5 Concentrations \n14 \n TSP Concentrations \n15 \n Dust Deposition \n15 \n Background Values \n15 \n6 ASSESSMENT APPROACH AND DISPERSION MODELLING LIMITATIONS \n16 \n7 DUST CONTROL MEASURES \n18 \n8 ESTIMATED EMISSIONS \n19 \n9 CONSTRUCTION PHASE IMPACTS \n23 \n9.1 Clearing / Excavation \n23 \n9.2 Haul Road \n23 \n9.3 Haulage and Heavy Plant and Equipment \n23 \n9.4 Wind Erosion \n23 \n10 OPERATIONAL PHASE IMPACT ASSESSMENT \n24 \n10.1 Annual Average Concentrations \n24 \n TSP \n24 \n PM10 \n26 \n PM2.5 \n28 \n Dust Deposition Level \n30 \n10.2 24-hour average concentrations \n32'),
#  Document(metadata={'producer': 'Microsoft® Word 2013', 'creator': 'Microsoft® Word 2013', 'creationdate': '2017-09-29T07:53:36+10:00', 'source': 'Att 5. Air Quality Assessment 4567 Old Northern Road Maroota.pdf', 'file_path': 'Att 5. Air Quality Assessment 4567 Old Northern Road Maroota.pdf', 'total_pages': 63, 'format': 'PDF 1.5', 'title': 'Air Quality Assessment – Lot 1 DP 590937 AT 4567 Old Northern Road, Maroota Proposed Sand Quarry', 'author': 'Deanna Tuxford', 'subject': 'PF Formation', 'keywords': '', 'moddate': '2018-05-28T14:58:20+10:00', 'trapped': '', 'modDate': "D:20180528145820+10'00'", 'creationDate': "D:20170929075336+10'00'", 'page': 4}, page_content='24 \n10.1 Annual Average Concentrations \n24 \n TSP \n24 \n PM10 \n26 \n PM2.5 \n28 \n Dust Deposition Level \n30 \n10.2 24-hour average concentrations \n32 \n Introduction \n32 \n PM10 \n32 \n PM2.5 \n37 \n11 GREENHOUSE GAS ASSESSMENT \n42 \n11.1 Introduction \n42 \n11.2 Methodology \n42 \n11.3 Emission Estimates \n43 \n12 CONCLUSION \n45 \n13 REFERENCES \n46 \nAPPENDIX A MAROOTA PUBLIC SCHOOL WINDROSES \nA-1 \nAPPENDIX B MODEL SET UP \nB-1 \nAPPENDIX C EMISSION ESTIMATES \nC-1 \nC.1 Emission Estimates \nC-1'),
#  Document(metadata={'producer': 'Microsoft® Word 2013', 'creator': 'Microsoft® Word 2013', 'creationdate': '2017-09-29T07:53:36+10:00', 'source': 'Att 5. Air Quality Assessment 4567 Old Northern Road Maroota.pdf', 'file_path': 'Att 5. Air Quality Assessment 4567 Old Northern Road Maroota.pdf', 'total_pages': 63, 'format': 'PDF 1.5', 'title': 'Air Quality Assessment – Lot 1 DP 590937 AT 4567 Old Northern Road, Maroota Proposed Sand Quarry', 'author': 'Deanna Tuxford', 'subject': 'PF Formation', 'keywords': '', 'moddate': '2018-05-28T14:58:20+10:00', 'trapped': '', 'modDate': "D:20180528145820+10'00'", 'creationDate': "D:20170929075336+10'00'", 'page': 5}, page_content='20477B PF Formation Maroota Air Quality_R1.docx \nvi \nJob ID 20477 | AQU-NW-005-20477 \nList of Tables \nTable 3.1: Receptor Locations \n2 \nTable 3.2: NSW EPA impact assessment criteria for Particulate Matter \n4 \nTable 3.3: EPA Criteria for Dust (Insoluble Solids) Fallout \n5 \nTable 5.1: Climate Averages for the Peats Ridge Station \n7 \nTable 5.2: Inverse of the Monin-Obukhov length L with respect to atmospheric stability \n10 \nTable 5.3: Annual average PM10 and PM2.5 Concentrations at EPA Monitoring Sites \n15 \nTable 5.4: Annual Average Dust Deposition Data (g/m2/month) \n15 \nTable 8.1: Summary of source allocation \n20 \nTable 8.2: Estimated dust emissions – annual average \n22 \nTable 8.3: Estimated annual dust emissions based on maximum daily production scenario (worst case)\n \n22 \nTable 10.1: Predicted Annual Average TSP Concentrations \n24 \nTable 10.2: Predicted Annual Average PM10 Concentrations \n26 \nTable 10.3: Predicted Annual Average PM2.5 Concentrations \n28'),
#  Document(metadata={'producer': 'Microsoft® Word 2013', 'creator': 'Microsoft® Word 2013', 'creationdate': '2017-09-29T07:53:36+10:00', 'source': 'Att 5. Air Quality Assessment 4567 Old Northern Road Maroota.pdf', 'file_path': 'Att 5. Air Quality Assessment 4567 Old Northern Road Maroota.pdf', 'total_pages': 63, 'format': 'PDF 1.5', 'title': 'Air Quality Assessment – Lot 1 DP 590937 AT 4567 Old Northern Road, Maroota Proposed Sand Quarry', 'author': 'Deanna Tuxford', 'subject': 'PF Formation', 'keywords': '', 'moddate': '2018-05-28T14:58:20+10:00', 'trapped': '', 'modDate': "D:20180528145820+10'00'", 'creationDate': "D:20170929075336+10'00'", 'page': 5}, page_content='24 \nTable 10.2: Predicted Annual Average PM10 Concentrations \n26 \nTable 10.3: Predicted Annual Average PM2.5 Concentrations \n28 \nTable 10.4: Predicted Annual Average Dust Deposition Levels \n30 \nTable 10.5: Maximum predicted 24-Hour Average PM10 concentrations \n32 \nTable 10.6: Maximum predicted 24-Hour Average PM2.5 concentrations \n37 \nTable 11.1: Diesel transport GHG emission factors \n43 \nTable 11.2: Estimated CO2-e (tonnes) for Diesel Consumption \n44 \n \nList of Figures \nFigure 3-1: Location of the Site and Sensitive Receptors \n3 \nFigure 5-1: Wind Roses for 2015 (Left: BoM Richmond RAAF AWS, Right: Maroota Public School) \n9 \nFigure 5-2: Annual statistics of 1/L by hour of the day \n11 \nFigure 5-3: Annual distribution of stability type by hour of the day \n12 \nFigure 5-4: Monitoring Locations \n13 \nFigure 5-5: Measured 24-hour average PM10 concentrations for Maroota Public School TEOM \n14 \nFigure 7-1: Photographs of vegetation between proposal and R5 \n18 \nFigure 8-1: Source Locations \n20'),
#  Document(metadata={'producer': 'Microsoft® Word 2013', 'creator': 'Microsoft® Word 2013', 'creationdate': '2017-09-29T07:53:36+10:00', 'source': 'Att 5. Air Quality Assessment 4567 Old Northern Road Maroota.pdf', 'file_path': 'Att 5. Air Quality Assessment 4567 Old Northern Road Maroota.pdf', 'total_pages': 63, 'format': 'PDF 1.5', 'title': 'Air Quality Assessment – Lot 1 DP 590937 AT 4567 Old Northern Road, Maroota Proposed Sand Quarry', 'author': 'Deanna Tuxford', 'subject': 'PF Formation', 'keywords': '', 'moddate': '2018-05-28T14:58:20+10:00', 'trapped': '', 'modDate': "D:20180528145820+10'00'", 'creationDate': "D:20170929075336+10'00'", 'page': 5}, page_content='14 \nFigure 7-1: Photographs of vegetation between proposal and R5 \n18 \nFigure 8-1: Source Locations \n20 \nFigure 10-1: Predicted Annual Average TSP Concentration – Cumulative (\uf06dg/m3) \n25 \nFigure 10-2: Predicted Annual Average PM10 Concentration – Cumulative (\uf06dg/m3) \n27 \nFigure 10-3: Predicted Annual Average PM2.5 Concentration – Cumulative (\uf06dg/m3) \n29 \nFigure 10-4: Predicted Annual Average Dust Deposition Concentration (g/m2/month) \n31 \nFigure 10-5: Maximum predicted 24-Hour average PM10 Concentration – proposal-only (\uf06dg/m3) \n33 \nFigure 10-6: 24-hour average PM10 concentration – Proposal-only plus Background (Worst Day \nOperations) (\uf06dg/m3) – Receptor 5 and Receptor 7 \n35 \nFigure 10-7: 24-hour average PM10 concentration – Proposal-only plus Background (Worst Day \nOperations) (\uf06dg/m3) – Receptor 8 and Maroota Public School \n36 \nFigure 10-8: Maximum predicted 24-Hour average PM2.5 Concentration – Proposal-only (\uf06dg/m3) \n38'),
#  Document(metadata={'producer': 'Microsoft® Word 2013', 'creator': 'Microsoft® Word 2013', 'creationdate': '2017-09-29T07:53:36+10:00', 'source': 'Att 5. Air Quality Assessment 4567 Old Northern Road Maroota.pdf', 'file_path': 'Att 5. Air Quality Assessment 4567 Old Northern Road Maroota.pdf', 'total_pages': 63, 'format': 'PDF 1.5', 'title': 'Air Quality Assessment – Lot 1 DP 590937 AT 4567 Old Northern Road, Maroota Proposed Sand Quarry', 'author': 'Deanna Tuxford', 'subject': 'PF Formation', 'keywords': '', 'moddate': '2018-05-28T14:58:20+10:00', 'trapped': '', 'modDate': "D:20180528145820+10'00'", 'creationDate': "D:20170929075336+10'00'", 'page': 6}, page_content='20477B PF Formation Maroota Air Quality_R1.docx \nvii \nJob ID 20477 | AQU-NW-005-20477 \nFigure 10-9: 24-hour average PM2.5 concentration – Proposal-only plus Background (Worst Day \nOperations) (\uf06dg/m3) – Receptor 5 and Receptor 7 \n40 \nFigure 10-10: 24-hour average PM2.5 concentration – Proposal-only plus Background (Worst Day \nOperations) (\uf06dg/m3) – Receptor 8 and Maroota Public School \n41 \nFigure 11-1: Overview of Scopes and Emissions across a Reporting Entity \n43'),
#  Document(metadata={'producer': 'Microsoft® Word 2013', 'creator': 'Microsoft® Word 2013', 'creationdate': '2017-09-29T07:53:36+10:00', 'source': 'Att 5. Air Quality Assessment 4567 Old Northern Road Maroota.pdf', 'file_path': 'Att 5. Air Quality Assessment 4567 Old Northern Road Maroota.pdf', 'total_pages': 63, 'format': 'PDF 1.5', 'title': 'Air Quality Assessment – Lot 1 DP 590937 AT 4567 Old Northern Road, Maroota Proposed Sand Quarry', 'author': 'Deanna Tuxford', 'subject': 'PF Formation', 'keywords': '', 'moddate': '2018-05-28T14:58:20+10:00', 'trapped': '', 'modDate': "D:20180528145820+10'00'", 'creationDate': "D:20170929075336+10'00'", 'page': 7}, page_content='20477B PF Formation Maroota Air Quality_R1.docx \n1 \nJob Number 20477 | AQU-NW-005-20477 \n1 \nINTRODUCTION \nPacific Environment has prepared this air quality and greenhouse gas assessment for PF Formation (the \nProponent). It assesses the air quality impacts associated with the proposed Maroota sand quarry on \nLot 1 DP 590937 Old Northern Road, Maroota (the proposal). \nThe assessment was prepared in accordance with the NSW EPA “Approved Methods for the Modelling \nand Assessment of Air Pollutants in NSW” (Approved Methods) (NSW EPA, 2016). \n2 \nPROPOSAL DESCRIPTION \nThe proponent proposes to develop and operate a sand quarry located on Lot 1 DP 590937 at 4567 \nOld Northern Road, Maroota. Key features of the proposal, as they relate to the air quality assessment \nare: \n■ \nThe operation of a sand quarry extracting up to a maximum of 250,000 tonnes of product per \nyear. \n■ \nQuarrying and related activities will occur primarily between 7am and 6pm Monday to'),
#  Document(metadata={'producer': 'Microsoft® Word 2013', 'creator': 'Microsoft® Word 2013', 'creationdate': '2017-09-29T07:53:36+10:00', 'source': 'Att 5. Air Quality Assessment 4567 Old Northern Road Maroota.pdf', 'file_path': 'Att 5. Air Quality Assessment 4567 Old Northern Road Maroota.pdf', 'total_pages': 63, 'format': 'PDF 1.5', 'title': 'Air Quality Assessment – Lot 1 DP 590937 AT 4567 Old Northern Road, Maroota Proposed Sand Quarry', 'author': 'Deanna Tuxford', 'subject': 'PF Formation', 'keywords': '', 'moddate': '2018-05-28T14:58:20+10:00', 'trapped': '', 'modDate': "D:20180528145820+10'00'", 'creationDate': "D:20170929075336+10'00'", 'page': 7}, page_content='year. \n■ \nQuarrying and related activities will occur primarily between 7am and 6pm Monday to \nSaturday, excluding Sundays and public holidays, for a period of 20 years. Typical site activities \nwill include: \no \nDozer/excavator/loader clearing vegetation/topsoil, \no \nExcavator/loader for excavation of raw material, \no \nFront End Loader stockpiling raw material, \no \nFront End Loader loading road trucks in extraction cells, \no \nHauling on unsealed roads from extraction cells to sealed road, \no \nHauling product on sealed access road to processing plant, \no \nDry processing (screening), and \no \nWind erosion from active extraction cells, existing extraction areas and active \nstockpiles.'),
#  Document(metadata={'producer': 'Microsoft® Word 2013', 'creator': 'Microsoft® Word 2013', 'creationdate': '2017-09-29T07:53:36+10:00', 'source': 'Att 5. Air Quality Assessment 4567 Old Northern Road Maroota.pdf', 'file_path': 'Att 5. Air Quality Assessment 4567 Old Northern Road Maroota.pdf', 'total_pages': 63, 'format': 'PDF 1.5', 'title': 'Air Quality Assessment – Lot 1 DP 590937 AT 4567 Old Northern Road, Maroota Proposed Sand Quarry', 'author': 'Deanna Tuxford', 'subject': 'PF Formation', 'keywords': '', 'moddate': '2018-05-28T14:58:20+10:00', 'trapped': '', 'modDate': "D:20180528145820+10'00'", 'creationDate': "D:20170929075336+10'00'", 'page': 8}, page_content='20477B PF Formation Maroota Air Quality_R1.docx \n2 \nJob Number 20477 | AQU-NW-005-20477 \n3 \nLOCAL SETTING \nThe land use in the area surrounding the proposed development is primarily rural and bushland, \nalthough there is significant sand extraction activity in the area, both by PF Formation and other \ncompanies.  \nThe closest sensitive receptor locations being occupied dwellings are listed in Table 3.1 and presented \nin Figure 3-1. These receptors represent assessment locations in close proximity to the proposal. \nMaroota Public School, where monitoring of weather and dust are completed by a neighbouring \nquarry, has also been included in the assessment (see Figure 5-4). \nTable 3.1: Receptor Locations \nReceptor ID \nType \nEasting (m) \nNorthing (m) \nR1 \nResidence \n313594 \n6297473 \nR2 \nResidence \n313390 \n6296962 \nR3 \nResidence \n313553 \n6296934 \nR4 \nResidence \n313471 \n6296779 \nR5 \nResidence  \n313641 \n6296673 \nR6 \nResidence \n313651 \n6296554 \nR7 \nResidence \n313538 \n6296523 \nR8 \nResidence'),
#  Document(metadata={'producer': 'Microsoft® Word 2013', 'creator': 'Microsoft® Word 2013', 'creationdate': '2017-09-29T07:53:36+10:00', 'source': 'Att 5. Air Quality Assessment 4567 Old Northern Road Maroota.pdf', 'file_path': 'Att 5. Air Quality Assessment 4567 Old Northern Road Maroota.pdf', 'total_pages': 63, 'format': 'PDF 1.5', 'title': 'Air Quality Assessment – Lot 1 DP 590937 AT 4567 Old Northern Road, Maroota Proposed Sand Quarry', 'author': 'Deanna Tuxford', 'subject': 'PF Formation', 'keywords': '', 'moddate': '2018-05-28T14:58:20+10:00', 'trapped': '', 'modDate': "D:20180528145820+10'00'", 'creationDate': "D:20170929075336+10'00'", 'page': 8}, page_content='R4 \nResidence \n313471 \n6296779 \nR5 \nResidence  \n313641 \n6296673 \nR6 \nResidence \n313651 \n6296554 \nR7 \nResidence \n313538 \n6296523 \nR8 \nResidence \n313658 \n6296496 \nR9 \nResidence \n314308 \n6296507 \nR10 \nResidence \n314477 \n6296656 \nR11 \nResidence \n314164 \n6296730 \nR12 \nResidence \n314119 \n6296816 \nMaroota Public School \nSchool \n313523 \n6296477 \n \nThe development and operation of the quarry will take place over a 20 year period. It will involve the \nextraction of 10 hectares (ha) within Lot 1 DP 590937.  \nThe site location and sensitive receptors around the proposed site are shown in Figure 3-1.'),
#  Document(metadata={'producer': 'Microsoft® Word 2013', 'creator': 'Microsoft® Word 2013', 'creationdate': '2017-09-29T07:53:36+10:00', 'source': 'Att 5. Air Quality Assessment 4567 Old Northern Road Maroota.pdf', 'file_path': 'Att 5. Air Quality Assessment 4567 Old Northern Road Maroota.pdf', 'total_pages': 63, 'format': 'PDF 1.5', 'title': 'Air Quality Assessment – Lot 1 DP 590937 AT 4567 Old Northern Road, Maroota Proposed Sand Quarry', 'author': 'Deanna Tuxford', 'subject': 'PF Formation', 'keywords': '', 'moddate': '2018-05-28T14:58:20+10:00', 'trapped': '', 'modDate': "D:20180528145820+10'00'", 'creationDate': "D:20170929075336+10'00'", 'page': 9}, page_content='20477B PF Formation Maroota Air Quality_R1.docx \n3 \nJob Number 20477 | AQU-NW-005-20477 \n \nFigure 3-1: Location of the Site and Sensitive Receptors'),
#  Document(metadata={'producer': 'Microsoft® Word 2013', 'creator': 'Microsoft® Word 2013', 'creationdate': '2017-09-29T07:53:36+10:00', 'source': 'Att 5. Air Quality Assessment 4567 Old Northern Road Maroota.pdf', 'file_path': 'Att 5. Air Quality Assessment 4567 Old Northern Road Maroota.pdf', 'total_pages': 63, 'format': 'PDF 1.5', 'title': 'Air Quality Assessment – Lot 1 DP 590937 AT 4567 Old Northern Road, Maroota Proposed Sand Quarry', 'author': 'Deanna Tuxford', 'subject': 'PF Formation', 'keywords': '', 'moddate': '2018-05-28T14:58:20+10:00', 'trapped': '', 'modDate': "D:20180528145820+10'00'", 'creationDate': "D:20170929075336+10'00'", 'page': 10}, page_content='20477B PF Formation Maroota Air Quality_R1.docx \n4 \nJob Number 20477 | AQU-NW-005-20477 \n4 AIR QUALITY CRITERIA \nThe potential emissions to air from the proposal are summarised as follows: \n■ \nProposed activities described in Section 2 have the potential to generate fugitive dust \nemissions, particularly from sand extraction, hauling and site rehabilitation. \n■ \nCombustion of diesel in quarrying equipment will result in emissions of fine fractions of \nparticulate matter (PM10 and PM2.5), oxides of nitrogen (NOx), carbon monoxide (CO), sulfur \ndioxide (SO2) and organic compounds. This assessment focuses on the key pollutants of fine \nPM. \nIt is noted that emissions of PM from diesel exhaust are considered to be accounted for in the emission \nfactors for fugitive PM for relevant sources (i.e. dozers).  \n4.1 \nImpact Assessment Criteria \nThe Approved Methods specify air quality impact assessment criteria relevant for assessing impacts'),
#  Document(metadata={'producer': 'Microsoft® Word 2013', 'creator': 'Microsoft® Word 2013', 'creationdate': '2017-09-29T07:53:36+10:00', 'source': 'Att 5. Air Quality Assessment 4567 Old Northern Road Maroota.pdf', 'file_path': 'Att 5. Air Quality Assessment 4567 Old Northern Road Maroota.pdf', 'total_pages': 63, 'format': 'PDF 1.5', 'title': 'Air Quality Assessment – Lot 1 DP 590937 AT 4567 Old Northern Road, Maroota Proposed Sand Quarry', 'author': 'Deanna Tuxford', 'subject': 'PF Formation', 'keywords': '', 'moddate': '2018-05-28T14:58:20+10:00', 'trapped': '', 'modDate': "D:20180528145820+10'00'", 'creationDate': "D:20170929075336+10'00'", 'page': 10}, page_content='4.1 \nImpact Assessment Criteria \nThe Approved Methods specify air quality impact assessment criteria relevant for assessing impacts \nfrom air pollution (NSW EPA, 2016). The impact assessment criteria for pollutants relevant to this \nassessment refer to the total pollutant load in the environment and impacts from new sources of these \npollutants must be added to existing background levels for compliance assessment. In other words, \nconsideration of background dust levels needs to be made when using the goals outlined in the \nApproved Methods to assess potential impacts. \nThese criteria are health-based (i.e. they are set at levels to protect against health effects) and for PM10 \nand PM2.5 are consistent with the Amended National Environment Protection Measure for Ambient Air \nQuality (Ambient Air-NEPM) (NEPC, 2016). In addition, the Approved Methods include other measures of \nair quality, namely dust deposition and Total Suspended Particulates (TSP) which are not stated in the'),
#  Document(metadata={'producer': 'Microsoft® Word 2013', 'creator': 'Microsoft® Word 2013', 'creationdate': '2017-09-29T07:53:36+10:00', 'source': 'Att 5. Air Quality Assessment 4567 Old Northern Road Maroota.pdf', 'file_path': 'Att 5. Air Quality Assessment 4567 Old Northern Road Maroota.pdf', 'total_pages': 63, 'format': 'PDF 1.5', 'title': 'Air Quality Assessment – Lot 1 DP 590937 AT 4567 Old Northern Road, Maroota Proposed Sand Quarry', 'author': 'Deanna Tuxford', 'subject': 'PF Formation', 'keywords': '', 'moddate': '2018-05-28T14:58:20+10:00', 'trapped': '', 'modDate': "D:20180528145820+10'00'", 'creationDate': "D:20170929075336+10'00'", 'page': 10}, page_content='air quality, namely dust deposition and Total Suspended Particulates (TSP) which are not stated in the \nAmbient Air-NEPM. \nTable 3.2 presents the air quality goals for pollutants that are relevant to this study. It is important to note \nthat the criteria are applied to the cumulative impacts due to the proposal and other sources. \nTable 3.2: NSW EPA impact assessment criteria for Particulate Matter  \nPollutant \nStandard \nAveraging Period \nSource \nTSP \n90 \uf06dg/m3 \nAnnual \nNSW EPA (2016) \nPM10 \n50 \uf06dg/m3 \n24-Hour \nNSW EPA (2016) \n25 \uf06dg/m3 \nAnnual \nPM2.5 \n25 µg/m3 \n24-Hour \nNSW EPA (2016) \n8 µg/m3 \nAnnual \n62 µg/m3 \nAnnual \nNotes: \n\uf06dg/m3 – micrograms per cubic metre. \n \nIn addition to health impacts, airborne dust also has the potential to cause nuisance effects by \ndepositing on surfaces, including vegetation. Larger particles do not tend to remain suspended in the \natmosphere for long periods of time and will fall out relatively close to source. Dust deposition can soil'),
#  Document(metadata={'producer': 'Microsoft® Word 2013', 'creator': 'Microsoft® Word 2013', 'creationdate': '2017-09-29T07:53:36+10:00', 'source': 'Att 5. Air Quality Assessment 4567 Old Northern Road Maroota.pdf', 'file_path': 'Att 5. Air Quality Assessment 4567 Old Northern Road Maroota.pdf', 'total_pages': 63, 'format': 'PDF 1.5', 'title': 'Air Quality Assessment – Lot 1 DP 590937 AT 4567 Old Northern Road, Maroota Proposed Sand Quarry', 'author': 'Deanna Tuxford', 'subject': 'PF Formation', 'keywords': '', 'moddate': '2018-05-28T14:58:20+10:00', 'trapped': '', 'modDate': "D:20180528145820+10'00'", 'creationDate': "D:20170929075336+10'00'", 'page': 10}, page_content='atmosphere for long periods of time and will fall out relatively close to source. Dust deposition can soil \nmaterials and generally degrade aesthetic elements of the environment, and are assessed for \nnuisance or amenity impacts.  \nTable 3.3 shows the maximum acceptable increase in dust deposition over the existing dust levels from \nan amenity perspective. These criteria for dust deposition levels are set to protect against nuisance \nimpacts (NSW EPA, 2016).'),
#  Document(metadata={'producer': 'Microsoft® Word 2013', 'creator': 'Microsoft® Word 2013', 'creationdate': '2017-09-29T07:53:36+10:00', 'source': 'Att 5. Air Quality Assessment 4567 Old Northern Road Maroota.pdf', 'file_path': 'Att 5. Air Quality Assessment 4567 Old Northern Road Maroota.pdf', 'total_pages': 63, 'format': 'PDF 1.5', 'title': 'Air Quality Assessment – Lot 1 DP 590937 AT 4567 Old Northern Road, Maroota Proposed Sand Quarry', 'author': 'Deanna Tuxford', 'subject': 'PF Formation', 'keywords': '', 'moddate': '2018-05-28T14:58:20+10:00', 'trapped': '', 'modDate': "D:20180528145820+10'00'", 'creationDate': "D:20170929075336+10'00'", 'page': 11}, page_content='20477B PF Formation Maroota Air Quality_R1.docx \n5 \nJob Number 20477 | AQU-NW-005-20477 \nTable 3.3: EPA Criteria for Dust (Insoluble Solids) Fallout \nPollutant \nAveraging period \nMaximum increase  (due to \nProposal) \nMaximum total level \nDeposited dust \n(insoluble solids) \nAnnual average \n2 g/m2/month \n4 g/m2/month \nNote:  g/m2/month – grams per square metre per month. \n4.2 \nCrystalline Silica \nSilica (SiO2) is a naturally occurring mineral composed of silicon and oxygen. It exists in crystalline and \namorphous forms depending on the structural arrangement of the oxygen and silicon atoms. Only the \ncrystalline forms are known to be fibrogenic (causes the formation of fibres) and only the respirable \nparticles (those which are capable of reaching the gas exchange region of the lungs) are considered \nin determining health effects of crystalline silica. The three most common types of crystalline silica are \nquartz, tridymite and cristobalite.'),
#  Document(metadata={'producer': 'Microsoft® Word 2013', 'creator': 'Microsoft® Word 2013', 'creationdate': '2017-09-29T07:53:36+10:00', 'source': 'Att 5. Air Quality Assessment 4567 Old Northern Road Maroota.pdf', 'file_path': 'Att 5. Air Quality Assessment 4567 Old Northern Road Maroota.pdf', 'total_pages': 63, 'format': 'PDF 1.5', 'title': 'Air Quality Assessment – Lot 1 DP 590937 AT 4567 Old Northern Road, Maroota Proposed Sand Quarry', 'author': 'Deanna Tuxford', 'subject': 'PF Formation', 'keywords': '', 'moddate': '2018-05-28T14:58:20+10:00', 'trapped': '', 'modDate': "D:20180528145820+10'00'", 'creationDate': "D:20170929075336+10'00'", 'page': 11}, page_content='in determining health effects of crystalline silica. The three most common types of crystalline silica are \nquartz, tridymite and cristobalite.  \nHuman exposure to crystalline silica occurs most often during occupational activities that involve the \nworking of materials containing crystalline silica products (e.g. masonry, concrete, sandstone) or use or \nmanufacture of crystalline silica-containing products. Activities that involve cutting, grinding or \nbreaking of these materials can result in the liberation of particles in multiple size ranges.   \nCrystalline silica dust is found everywhere in the environment (i.e. not just in an occupational context) \ndue to natural, industrial and agricultural activities as it comprises 12% of the earth’s crust (EOG \nResources 2014).  \nWhilst the long term inhalation of silica dust may lead to the formation of scar tissue in the lungs, which'),
#  Document(metadata={'producer': 'Microsoft® Word 2013', 'creator': 'Microsoft® Word 2013', 'creationdate': '2017-09-29T07:53:36+10:00', 'source': 'Att 5. Air Quality Assessment 4567 Old Northern Road Maroota.pdf', 'file_path': 'Att 5. Air Quality Assessment 4567 Old Northern Road Maroota.pdf', 'total_pages': 63, 'format': 'PDF 1.5', 'title': 'Air Quality Assessment – Lot 1 DP 590937 AT 4567 Old Northern Road, Maroota Proposed Sand Quarry', 'author': 'Deanna Tuxford', 'subject': 'PF Formation', 'keywords': '', 'moddate': '2018-05-28T14:58:20+10:00', 'trapped': '', 'modDate': "D:20180528145820+10'00'", 'creationDate': "D:20170929075336+10'00'", 'page': 11}, page_content='Resources 2014).  \nWhilst the long term inhalation of silica dust may lead to the formation of scar tissue in the lungs, which \ncan result in the serious lung disease silicosis, this is regarded exclusively as a work place exposure issue \nthat is associated with long-term exposure to high levels of respirable crystalline silica (RCS).  \nThe World Health Organization’s Concise International Chemical Assessment Document on Crystalline \nSilica, Quartz (CICAD, 2000) states that “there are no known adverse health effects associated with the \nnon-occupational exposure to quartz”.  \nIn addition, an Australian Government Senate Committee (2005) report identified that there are no \nreports in the international literature of individuals developing silicosis as a result of exposure to non-\noccupational levels (i.e. levels outside the work place) of silica dust, and an expert appearing before \nthe committee confirmed the potential for such an occurrence as being very remote.'),
#  Document(metadata={'producer': 'Microsoft® Word 2013', 'creator': 'Microsoft® Word 2013', 'creationdate': '2017-09-29T07:53:36+10:00', 'source': 'Att 5. Air Quality Assessment 4567 Old Northern Road Maroota.pdf', 'file_path': 'Att 5. Air Quality Assessment 4567 Old Northern Road Maroota.pdf', 'total_pages': 63, 'format': 'PDF 1.5', 'title': 'Air Quality Assessment – Lot 1 DP 590937 AT 4567 Old Northern Road, Maroota Proposed Sand Quarry', 'author': 'Deanna Tuxford', 'subject': 'PF Formation', 'keywords': '', 'moddate': '2018-05-28T14:58:20+10:00', 'trapped': '', 'modDate': "D:20180528145820+10'00'", 'creationDate': "D:20170929075336+10'00'", 'page': 11}, page_content='the committee confirmed the potential for such an occurrence as being very remote.   \nA literature review on the potential impacts to health from exposure to crustal material in Port Hedland, \nWA, states “exposure to airborne quartz carries the risk of silicosis, but only with prolonged exposure to \nconcentrations greater than 200 µg/m3” (Department of Health, 2007).   \nIn Australia, the occupational exposure standards for respirable crystalline silica are defined by Safe \nWork Australia. The national exposure standard for respirable crystalline silica is 100µg/m3 (Time \nWeighted Average (TWA))a.  Although the occupational standard is not applicable to the assessment \nof the ambient air quality, the risk of silicosis among people living in areas surrounding activities such as \nquarrying would therefore be considered minimal provided the concentration of respirable particles at \nthe source was acceptable in terms of occupational safety.'),
#  Document(metadata={'producer': 'Microsoft® Word 2013', 'creator': 'Microsoft® Word 2013', 'creationdate': '2017-09-29T07:53:36+10:00', 'source': 'Att 5. Air Quality Assessment 4567 Old Northern Road Maroota.pdf', 'file_path': 'Att 5. Air Quality Assessment 4567 Old Northern Road Maroota.pdf', 'total_pages': 63, 'format': 'PDF 1.5', 'title': 'Air Quality Assessment – Lot 1 DP 590937 AT 4567 Old Northern Road, Maroota Proposed Sand Quarry', 'author': 'Deanna Tuxford', 'subject': 'PF Formation', 'keywords': '', 'moddate': '2018-05-28T14:58:20+10:00', 'trapped': '', 'modDate': "D:20180528145820+10'00'", 'creationDate': "D:20170929075336+10'00'", 'page': 11}, page_content='the source was acceptable in terms of occupational safety. \nNSW EPA has not set any impact assessment criteria for crystalline silica. The Victorian EPA has adopted \nan ambient assessment criterion for mining and extractive industries of 3 µg/m3 (annual average as \nPM2.5b) (VEPA, 2007). This has been derived from the Reference Exposure Level (REL) c set by the \n                                                           \na TWA - the average airborne concentration of a particular substance when calculated over a normal eight-hour \nworking day, for a five-day working week. \nb PM2.5  - particles with an equivalent aerodynamic diameter of less than approximately 2.5µm.'),
#  Document(metadata={'producer': 'Microsoft® Word 2013', 'creator': 'Microsoft® Word 2013', 'creationdate': '2017-09-29T07:53:36+10:00', 'source': 'Att 5. Air Quality Assessment 4567 Old Northern Road Maroota.pdf', 'file_path': 'Att 5. Air Quality Assessment 4567 Old Northern Road Maroota.pdf', 'total_pages': 63, 'format': 'PDF 1.5', 'title': 'Air Quality Assessment – Lot 1 DP 590937 AT 4567 Old Northern Road, Maroota Proposed Sand Quarry', 'author': 'Deanna Tuxford', 'subject': 'PF Formation', 'keywords': '', 'moddate': '2018-05-28T14:58:20+10:00', 'trapped': '', 'modDate': "D:20180528145820+10'00'", 'creationDate': "D:20170929075336+10'00'", 'page': 12}, page_content='20477B PF Formation Maroota Air Quality_R1.docx \n6 \nJob Number 20477 | AQU-NW-005-20477 \nCalifornia EPA Office of Environmental Health Hazard Assessment of 3 µg/m3 (annual average as PM4d) \n(OEHHA, 2005), at or below which “no adverse effects are expected for indefinite exposure”. \nAn extensive ambient crystalline silica sampling program completed in the United States (EOG \nResources 2014) collected data between October 2012 and October 2013 inside the fence lines of four \nactive sand quarrying facilities. The report concluded that the long-term (fifteen-month) average \nambient PM4 crystalline silica concentrations both upwind and downwind of the facilities were less than \n6% of the 3 µg/m3 REL, the measured 24-hour average concentrations were almost entirely below \n1.5 µg/m3 both upwind and downwind and were due in part to the regional background levels of PM4 \ncrystalline silica that are present in the ambient air throughout the US, and the differences between'),
#  Document(metadata={'producer': 'Microsoft® Word 2013', 'creator': 'Microsoft® Word 2013', 'creationdate': '2017-09-29T07:53:36+10:00', 'source': 'Att 5. Air Quality Assessment 4567 Old Northern Road Maroota.pdf', 'file_path': 'Att 5. Air Quality Assessment 4567 Old Northern Road Maroota.pdf', 'total_pages': 63, 'format': 'PDF 1.5', 'title': 'Air Quality Assessment – Lot 1 DP 590937 AT 4567 Old Northern Road, Maroota Proposed Sand Quarry', 'author': 'Deanna Tuxford', 'subject': 'PF Formation', 'keywords': '', 'moddate': '2018-05-28T14:58:20+10:00', 'trapped': '', 'modDate': "D:20180528145820+10'00'", 'creationDate': "D:20170929075336+10'00'", 'page': 12}, page_content='crystalline silica that are present in the ambient air throughout the US, and the differences between \nupwind and downwind measurements were usually too low to be detected (further supporting the fact \nthat the sand quarrying operations were not having a detrimental impact on local air quality). This is \nunderstood to be the most extensive ambient monitoring of PM4 crystalline silica in the vicinity of sand \nquarrying operations to have ever been undertaken and clearly demonstrates that sand quarrying \noperations do not result in ambient levels of PM4 crystalline silica that are considered to be detrimental \nto the general population. Sampling completed in the vicinity of coal mining operations in the Hunter \nValley, NSW between February and October 2010 (Morrison and Nelson, 2011) crystalline silica \nconcentrations were in the range 0.5 – 1.8 µg/m³ (PM4). These values are significantly below the'),
#  Document(metadata={'producer': 'Microsoft® Word 2013', 'creator': 'Microsoft® Word 2013', 'creationdate': '2017-09-29T07:53:36+10:00', 'source': 'Att 5. Air Quality Assessment 4567 Old Northern Road Maroota.pdf', 'file_path': 'Att 5. Air Quality Assessment 4567 Old Northern Road Maroota.pdf', 'total_pages': 63, 'format': 'PDF 1.5', 'title': 'Air Quality Assessment – Lot 1 DP 590937 AT 4567 Old Northern Road, Maroota Proposed Sand Quarry', 'author': 'Deanna Tuxford', 'subject': 'PF Formation', 'keywords': '', 'moddate': '2018-05-28T14:58:20+10:00', 'trapped': '', 'modDate': "D:20180528145820+10'00'", 'creationDate': "D:20170929075336+10'00'", 'page': 12}, page_content='concentrations were in the range 0.5 – 1.8 µg/m³ (PM4). These values are significantly below the \nthreshold value of 3 µg/m³ at or below which “no adverse effects are expected for indefinite \nexposure”. \n \nAs presented in the air quality assessment (see Section 10), the maximum annual average PM10 \nconcentration at the most affected residence due to the proposal-only is predicted to be 5 µg/m3 (see \nTable 10.2 – R5 under worst case operations). Given that crystalline silica would be a small fraction of \nPM10 concentrations, any PM4 crystalline silica levels would be significantly below levels that may be of \nconcern. \n \n \n                                                                                                                                                                                     \nc RELs are used by the California Environmental Protection Agency as indicators of potential adverse health effects.'),
#  Document(metadata={'producer': 'Microsoft® Word 2013', 'creator': 'Microsoft® Word 2013', 'creationdate': '2017-09-29T07:53:36+10:00', 'source': 'Att 5. Air Quality Assessment 4567 Old Northern Road Maroota.pdf', 'file_path': 'Att 5. Air Quality Assessment 4567 Old Northern Road Maroota.pdf', 'total_pages': 63, 'format': 'PDF 1.5', 'title': 'Air Quality Assessment – Lot 1 DP 590937 AT 4567 Old Northern Road, Maroota Proposed Sand Quarry', 'author': 'Deanna Tuxford', 'subject': 'PF Formation', 'keywords': '', 'moddate': '2018-05-28T14:58:20+10:00', 'trapped': '', 'modDate': "D:20180528145820+10'00'", 'creationDate': "D:20170929075336+10'00'", 'page': 12}, page_content='c RELs are used by the California Environmental Protection Agency as indicators of potential adverse health effects. \nAn REL is a concentration level (g/m3) or dose (mg/kg/day) at (or below) which no adverse health effects are \nanticipated for a specified time period. RELs are generally based on the most sensitive adverse health effect \nreported in the medical and toxicological literature. RELs are designed to protect the most sensitive individuals in the \npopulation by the inclusion of margins of safety. \nd PM4  - \nparticles with an equivalent aerodynamic diameter of less than approximately 4µm.'),
# ...
#  Document(metadata={'producer': 'Microsoft® Word 2013', 'creator': 'Microsoft® Word 2013', 'creationdate': '2017-09-29T07:53:36+10:00', 'source': 'Att 5. Air Quality Assessment 4567 Old Northern Road Maroota.pdf', 'file_path': 'Att 5. Air Quality Assessment 4567 Old Northern Road Maroota.pdf', 'total_pages': 63, 'format': 'PDF 1.5', 'title': 'Air Quality Assessment – Lot 1 DP 590937 AT 4567 Old Northern Road, Maroota Proposed Sand Quarry', 'author': 'Deanna Tuxford', 'subject': 'PF Formation', 'keywords': '', 'moddate': '2018-05-28T14:58:20+10:00', 'trapped': '', 'modDate': "D:20180528145820+10'00'", 'creationDate': "D:20170929075336+10'00'", 'page': 62}, page_content='3.96 kg/VKT\n6.4 % silt content\n75 % control\nUnloading sand to processing stockpile at Cell 1A\n23\n             \n120,000\n   \nt/y\n0.00019 kg/t\n0.58 average of (wind speed/2.2)^1.3 in m/s\n5 moisture content (%)\nFEL Loading sand from processing stockpile at Cell 1A\n23\n             \n120,000\n   \nt/y\n0.00019 kg/t\n0.58 average of (wind speed/2.2)^1.3 in m/s\n5 moisture content (%)\nFEL Unloading sand to Dry Processing at Cell 1A\n23\n             \n120,000\n   \nt/y\n0.00019 kg/t\n0.58 average of (wind speed/2.2)^1.3 in m/s\n5 moisture content (%)\nScreening (uncontrolled) at Cell 1A\n1,500\n        \n120,000\n   \nt/y\n0.0125 kg/t\nFEL Loading sand from Product Stockpile to haul trucks for direct sale to market\n23\n             \n120,000\n   \nt/y\n0.00019 kg/t\n0.58 average of (wind speed/2.2)^1.3 in m/s\n5 moisture content (%)\nHauling Product to Old Northern Road (sealed)\n608\n           \n120,000\n   \nt/y\n0.005 kg/t\n40 t/load\n75 Vehicle gross mass (t)\n1.6 km/return trip\n0.13 kg/VKT\n0.4 g/m2 silt loading'),
#  Document(metadata={'producer': 'Microsoft® Word 2013', 'creator': 'Microsoft® Word 2013', 'creationdate': '2017-09-29T07:53:36+10:00', 'source': 'Att 5. Air Quality Assessment 4567 Old Northern Road Maroota.pdf', 'file_path': 'Att 5. Air Quality Assessment 4567 Old Northern Road Maroota.pdf', 'total_pages': 63, 'format': 'PDF 1.5', 'title': 'Air Quality Assessment – Lot 1 DP 590937 AT 4567 Old Northern Road, Maroota Proposed Sand Quarry', 'author': 'Deanna Tuxford', 'subject': 'PF Formation', 'keywords': '', 'moddate': '2018-05-28T14:58:20+10:00', 'trapped': '', 'modDate': "D:20180528145820+10'00'", 'creationDate': "D:20170929075336+10'00'", 'page': 62}, page_content='608\n           \n120,000\n   \nt/y\n0.005 kg/t\n40 t/load\n75 Vehicle gross mass (t)\n1.6 km/return trip\n0.13 kg/VKT\n0.4 g/m2 silt loading\nHauling from Site to PF Formation Processing Area Cell 4 (sealed)\n723\n           \n180,000\n   \nt/y\n0.004 kg/t\n32 t/load\n48 Vehicle gross mass (t)\n1.6 km/return trip\n0.08 kg/VKT\n0.4 g/m2 silt loading\nUnloading to PF Formation Processing Area Cell 4\n34\n             \n180,000\n   \nt/y\n0.00019 kg/t\n0.58 average of (wind speed/2.2)^1.3 in m/s\n5 moisture content (%)\nWind Erosion\nWE - Extraction Area (Cell 3C)\n1,139\n        \n1.3\n          \nha\n0.1 kg/ha/h\n8,760 h\n0 % control\nWE - Exposed Area (Cell 3B)\n289\n           \n1.1\n          \nha\n0.1 kg/ha/h\n8,760 h\n70 % control\nWE - Exposed Area (Cell 1A)\n701\n           \n0.80\n        \nha\n0.1 kg/ha/h\n8,760 h\n0 % control\nWE - Extraction Stockpile (Cell 3C)\n88\n             \n0.10\n        \nha\n0.1 kg/ha/h\n8,760 h\n0 % control\nWE - Post Dry Processing Stockpile (Cell 1A)\n88\n             \n0.10\n        \nha\n0.1 kg/ha/h\n8,760 h'),
#  Document(metadata={'producer': 'Microsoft® Word 2013', 'creator': 'Microsoft® Word 2013', 'creationdate': '2017-09-29T07:53:36+10:00', 'source': 'Att 5. Air Quality Assessment 4567 Old Northern Road Maroota.pdf', 'file_path': 'Att 5. Air Quality Assessment 4567 Old Northern Road Maroota.pdf', 'total_pages': 63, 'format': 'PDF 1.5', 'title': 'Air Quality Assessment – Lot 1 DP 590937 AT 4567 Old Northern Road, Maroota Proposed Sand Quarry', 'author': 'Deanna Tuxford', 'subject': 'PF Formation', 'keywords': '', 'moddate': '2018-05-28T14:58:20+10:00', 'trapped': '', 'modDate': "D:20180528145820+10'00'", 'creationDate': "D:20170929075336+10'00'", 'page': 62}, page_content='0.10\n        \nha\n0.1 kg/ha/h\n8,760 h\n0 % control\nWE - Post Dry Processing Stockpile (Cell 1A)\n88\n             \n0.10\n        \nha\n0.1 kg/ha/h\n8,760 h\n0 % control\nTOTAL EMISSIONS\n15,198\n      \nACTIVITY\nPM10 (kg/y)\nIntensity\nUnits\nEmission factor Units\nVariable 1\nUnits\nVariable \n2\nUnits\nVariable 3 Units\nVariable 3\nUnits\nVariable 4 Units\nControl Units\nExtraction Area\nDozer stripping topsoil/extracting sand \n1,648\n                   \n1,600\n      \nh/y\n2.1 kg/h\n15 silt content in %\n5 moisture content (%)\n50 % control\nExcavator loading sand to trucks from extraction area\n27\n                       \n300,000\n   \nt/y\n0.00009 kg/t\n0.58 average of (wind speed/2.2)^1.3 in m/s\n5 moisture content (%)\nHauling from extraction Cell 3C to Cell 1A  (unsealed)\n881\n                      \n120,000\n   \nt/y\n0.029 kg/t\n40 t/load\n75 Vehicle gross mass (t)\n1.1 km/return trip\n1.07 kg/VKT\n6.4 % silt content\n75 % control\nUnloading sand to processing stockpile at Cell 1A\n11\n                       \n120,000\n   \nt/y'),
#  Document(metadata={'producer': 'Microsoft® Word 2013', 'creator': 'Microsoft® Word 2013', 'creationdate': '2017-09-29T07:53:36+10:00', 'source': 'Att 5. Air Quality Assessment 4567 Old Northern Road Maroota.pdf', 'file_path': 'Att 5. Air Quality Assessment 4567 Old Northern Road Maroota.pdf', 'total_pages': 63, 'format': 'PDF 1.5', 'title': 'Air Quality Assessment – Lot 1 DP 590937 AT 4567 Old Northern Road, Maroota Proposed Sand Quarry', 'author': 'Deanna Tuxford', 'subject': 'PF Formation', 'keywords': '', 'moddate': '2018-05-28T14:58:20+10:00', 'trapped': '', 'modDate': "D:20180528145820+10'00'", 'creationDate': "D:20170929075336+10'00'", 'page': 62}, page_content='1.07 kg/VKT\n6.4 % silt content\n75 % control\nUnloading sand to processing stockpile at Cell 1A\n11\n                       \n120,000\n   \nt/y\n0.00009 kg/t\n0.58 average of (wind speed/2.2)^1.3 in m/s\n5 moisture content (%)\nFEL Loading sand from processing stockpile at Cell 1A\n11\n                       \n120,000\n   \nt/y\n0.00009 kg/t\n0.58 average of (wind speed/2.2)^1.3 in m/s\n5 moisture content (%)\nFEL Unloading sand to Dry Processing at Cell 1A\n11\n                       \n120,000\n   \nt/y\n0.00009 kg/t\n0.58 average of (wind speed/2.2)^1.3 in m/s\n5 moisture content (%)\nScreening (uncontrolled) at Cell 1A\n516\n                      \n120,000\n   \nt/y\n0.0043 kg/t\nFEL Loading sand from Product Stockpile to haul trucks for direct sale to market\n11\n                       \n120,000\n   \nt/y\n0.00009 kg/t\n0.58 average of (wind speed/2.2)^1.3 in m/s\n5 moisture content (%)\nHauling Product to Old Northern Road (sealed)\n117\n                      \n120,000\n   \nt/y\n0.001 kg/t\n40 t/load\n75 Vehicle gross mass (t)'),
#  Document(metadata={'producer': 'Microsoft® Word 2013', 'creator': 'Microsoft® Word 2013', 'creationdate': '2017-09-29T07:53:36+10:00', 'source': 'Att 5. Air Quality Assessment 4567 Old Northern Road Maroota.pdf', 'file_path': 'Att 5. Air Quality Assessment 4567 Old Northern Road Maroota.pdf', 'total_pages': 63, 'format': 'PDF 1.5', 'title': 'Air Quality Assessment – Lot 1 DP 590937 AT 4567 Old Northern Road, Maroota Proposed Sand Quarry', 'author': 'Deanna Tuxford', 'subject': 'PF Formation', 'keywords': '', 'moddate': '2018-05-28T14:58:20+10:00', 'trapped': '', 'modDate': "D:20180528145820+10'00'", 'creationDate': "D:20170929075336+10'00'", 'page': 62}, page_content='Hauling Product to Old Northern Road (sealed)\n117\n                      \n120,000\n   \nt/y\n0.001 kg/t\n40 t/load\n75 Vehicle gross mass (t)\n1.6 km/return trip\n0.02 kg/VKT\n0.4 g/m2 silt loading\nHauling from Site to PF Formation Processing Area Cell 4 (sealed)\n219\n                      \n180,000\n   \nt/y\n0.001 kg/t\n32 t/load\n48 Vehicle gross mass (t)\n1.6 km/return trip\n0.02 kg/VKT\n0.4 g/m2 silt loading\nUnloading to PF Formation Processing Area Cell 4\n16\n                       \n180,000\n   \nt/y\n0.00009 kg/t\n0.58 average of (wind speed/2.2)^1.3 in m/s\n5 moisture content (%)\nWind Erosion\nWE - Extraction Area (Cell 3C)\n569\n                      \n1.3\n          \nha\n0.05 kg/ha/h\n8,760 h\n0 % control\nWE - Exposed Area (Cell 3B)\n145\n                      \n1.1\n          \nha\n0.05 kg/ha/h\n8,760 h\n70 % control\nWE - Exposed Area (Cell 1A)\n350\n                      \n0.80\n        \nha\n0.05 kg/ha/h\n8,760 h\n0 % control\nWE - Extraction Stockpile (Cell 3C)\n44\n                       \n0.10\n        \nha\n0.05 kg/ha/h'),
#  Document(metadata={'producer': 'Microsoft® Word 2013', 'creator': 'Microsoft® Word 2013', 'creationdate': '2017-09-29T07:53:36+10:00', 'source': 'Att 5. Air Quality Assessment 4567 Old Northern Road Maroota.pdf', 'file_path': 'Att 5. Air Quality Assessment 4567 Old Northern Road Maroota.pdf', 'total_pages': 63, 'format': 'PDF 1.5', 'title': 'Air Quality Assessment – Lot 1 DP 590937 AT 4567 Old Northern Road, Maroota Proposed Sand Quarry', 'author': 'Deanna Tuxford', 'subject': 'PF Formation', 'keywords': '', 'moddate': '2018-05-28T14:58:20+10:00', 'trapped': '', 'modDate': "D:20180528145820+10'00'", 'creationDate': "D:20170929075336+10'00'", 'page': 62}, page_content='0.80\n        \nha\n0.05 kg/ha/h\n8,760 h\n0 % control\nWE - Extraction Stockpile (Cell 3C)\n44\n                       \n0.10\n        \nha\n0.05 kg/ha/h\n8,760 h\n0 % control\nWE - Post Dry Processing Stockpile (Cell 1A)\n44\n                       \n0.10\n        \nha\n0.05 kg/ha/h\n8,760 h\n0 % control\nTOTAL EMISSIONS\n4,618\n                  \nACTIVITY\nPM2.5 (kg/y)\nIntensity\nUnits\nEmission factor Units\nVariable 1\nUnits\nVariable \n2\nUnits\nVariable 3 Units\nVariable 3\nUnits\nVariable 4 Units\nControl Units\nExtraction Area\nDozer stripping topsoil/extracting sand \n695\n                 \n1,600\n      \nh/y\n0.9 kg/h\n15 silt content in %\n5 moisture content (%)\n50 % control\nExcavator loading sand to trucks from extraction area\n4\n                     \n300,000\n   \nt/y\n0.00001 kg/t\n0.58 average of (wind speed/2.2)^1.3 in m/s\n5 moisture content (%)\nHauling from extraction Cell 3C to Cell 1A  (unsealed)\n88\n                   \n120,000\n   \nt/y\n0.003 kg/t\n40 t/load\n75 Vehicle gross mass (t)\n1.1 km/return trip\n0.11 kg/VKT'),
#  Document(metadata={'producer': 'Microsoft® Word 2013', 'creator': 'Microsoft® Word 2013', 'creationdate': '2017-09-29T07:53:36+10:00', 'source': 'Att 5. Air Quality Assessment 4567 Old Northern Road Maroota.pdf', 'file_path': 'Att 5. Air Quality Assessment 4567 Old Northern Road Maroota.pdf', 'total_pages': 63, 'format': 'PDF 1.5', 'title': 'Air Quality Assessment – Lot 1 DP 590937 AT 4567 Old Northern Road, Maroota Proposed Sand Quarry', 'author': 'Deanna Tuxford', 'subject': 'PF Formation', 'keywords': '', 'moddate': '2018-05-28T14:58:20+10:00', 'trapped': '', 'modDate': "D:20180528145820+10'00'", 'creationDate': "D:20170929075336+10'00'", 'page': 62}, page_content='88\n                   \n120,000\n   \nt/y\n0.003 kg/t\n40 t/load\n75 Vehicle gross mass (t)\n1.1 km/return trip\n0.11 kg/VKT\n6.4 % silt content\n75 % control\nUnloading sand to processing stockpile at Cell 1A\n2\n                     \n120,000\n   \nt/y\n0.00001 kg/t\n0.58 average of (wind speed/2.2)^1.3 in m/s\n5 moisture content (%)\nFEL Loading sand from processing stockpile at Cell 1A\n2\n                     \n120,000\n   \nt/y\n0.00001 kg/t\n0.58 average of (wind speed/2.2)^1.3 in m/s\n5 moisture content (%)\nFEL Unloading sand to Dry Processing at Cell 1A\n2\n                     \n120,000\n   \nt/y\n0.00001 kg/t\n0.58 average of (wind speed/2.2)^1.3 in m/s\n5 moisture content (%)\nScreening (uncontrolled) at Cell 1A\n45\n                   \n120,000\n   \nt/y\n0.0004 kg/t\nFEL Loading sand from Product Stockpile to haul trucks for direct sale to market\n2\n                     \n120,000\n   \nt/y\n0.00001 kg/t\n0.58 average of (wind speed/2.2)^1.3 in m/s\n5 moisture content (%)\nHauling Product to Old Northern Road (sealed)\n28'),
#  Document(metadata={'producer': 'Microsoft® Word 2013', 'creator': 'Microsoft® Word 2013', 'creationdate': '2017-09-29T07:53:36+10:00', 'source': 'Att 5. Air Quality Assessment 4567 Old Northern Road Maroota.pdf', 'file_path': 'Att 5. Air Quality Assessment 4567 Old Northern Road Maroota.pdf', 'total_pages': 63, 'format': 'PDF 1.5', 'title': 'Air Quality Assessment – Lot 1 DP 590937 AT 4567 Old Northern Road, Maroota Proposed Sand Quarry', 'author': 'Deanna Tuxford', 'subject': 'PF Formation', 'keywords': '', 'moddate': '2018-05-28T14:58:20+10:00', 'trapped': '', 'modDate': "D:20180528145820+10'00'", 'creationDate': "D:20170929075336+10'00'", 'page': 62}, page_content='120,000\n   \nt/y\n0.00001 kg/t\n0.58 average of (wind speed/2.2)^1.3 in m/s\n5 moisture content (%)\nHauling Product to Old Northern Road (sealed)\n28\n                   \n120,000\n   \nt/y\n0.0002 kg/t\n40 t/load\n75 Vehicle gross mass (t)\n1.6 km/return trip\n0.01 kg/VKT\n0.4 g/m2 silt loading\nHauling from Site to PF Formation Processing Area Cell 4 (sealed)\n53\n                   \n180,000\n   \nt/y\n0.0003 kg/t\n32 t/load\n48 Vehicle gross mass (t)\n1.6 km/return trip\n0.01 kg/VKT\n0.4 g/m2 silt loading\nUnloading to PF Formation Processing Area Cell 4\n2\n                     \n180,000\n   \nt/y\n0.00001 kg/t\n0.58 average of (wind speed/2.2)^1.3 in m/s\n5 moisture content (%)\nWind Erosion\nWE - Extraction Area (Cell 3C)\n85\n                   \n1.3\n          \nha\n0.0075 kg/ha/h\n8,760 h\n0 % control\nWE - Exposed Area (Cell 3B)\n22\n                   \n1.1\n          \nha\n0.0075 kg/ha/h\n8,760 h\n70 % control\nWE - Exposed Area (Cell 1A)\n53\n                   \n0.80\n        \nha\n0.0075 kg/ha/h\n8,760 h\n0 % control'),
#  Document(metadata={'producer': 'Microsoft® Word 2013', 'creator': 'Microsoft® Word 2013', 'creationdate': '2017-09-29T07:53:36+10:00', 'source': 'Att 5. Air Quality Assessment 4567 Old Northern Road Maroota.pdf', 'file_path': 'Att 5. Air Quality Assessment 4567 Old Northern Road Maroota.pdf', 'total_pages': 63, 'format': 'PDF 1.5', 'title': 'Air Quality Assessment – Lot 1 DP 590937 AT 4567 Old Northern Road, Maroota Proposed Sand Quarry', 'author': 'Deanna Tuxford', 'subject': 'PF Formation', 'keywords': '', 'moddate': '2018-05-28T14:58:20+10:00', 'trapped': '', 'modDate': "D:20180528145820+10'00'", 'creationDate': "D:20170929075336+10'00'", 'page': 62}, page_content='ha\n0.0075 kg/ha/h\n8,760 h\n70 % control\nWE - Exposed Area (Cell 1A)\n53\n                   \n0.80\n        \nha\n0.0075 kg/ha/h\n8,760 h\n0 % control\nWE - Extraction Stockpile (Cell 3C)\n7\n                     \n0.10\n        \nha\n0.0075 kg/ha/h\n8,760 h\n0 % control\nWE - Post Dry Processing Stockpile (Cell 1A)\n7\n                     \n0.10\n        \nha\n0.0075 kg/ha/h\n8,760 h\n0 % control\nTOTAL EMISSIONS\n1,095')]

# %%
# a simple function that removes \n newline from the content
def remove_ws(d):
    text = d.page_content.replace('\n','')
    d.page_content = text
    return d

# applied on the docs
docs = [remove_ws(d) for d in docs]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 8
#       5     return d
#       7 # applied on the docs
# ----> 8 docs = [remove_ws(d) for d in docs]
#
# NameError: name 'docs' is not defined

# %%
from genaicore import azure_openai_text_embeddings_llm
from langchain_community.vectorstores import FAISS
embeddings=azure_openai_text_embeddings_llm
# Creates the document retriever using docs and embeddings
db = FAISS.from_documents(docs, embeddings)



# Asking the retriever to do similarity search based on Query
query = """Extract the following information from the attached PDF report, starting from page 31 (onwards) under the section 'Annual Average Concentrations':

All environment parameters such as TSP, SO2, NO2, O3, Pb, PM2.5, PM10, deposited dust, CO, and HF.

The values for each parameter.

The dates when these values were measured.

Any relevant notes related to these measurements.

Please also check for cumulative values where applicable.

Additionally, from the section starting on page 93, extract the values for each residential location (R1 to R20) and check if any of the values mentioned under R1 to R20 exceed the following limits:

50 (24 hours for PM10) and 25 (Annual for PM10)

25 (24 hours for PM2.5) and 8 (Annual for PM2.5)

90 (Annual for TSP)

2 (Annual Increment for Dust Deposition) and 4 (Annual Cumulative for Dust Deposition)

The units of measurement (UOM) for these parameters are as follows:

For Dust Deposited: g/m²/day

For others: µg/m³

Please provide a comprehensive summary of your findings."""
answer = db.similarity_search(query)

# Building the retriever
retriever = db.as_retriever(search_kwargs={'k': 3})

# %%
def load_text_from_file(file_path):
    with open(file_path, 'r', encoding='utf-8') as file:
        text = file.read()
    return text

# Example usage
file_path = 'Environment_standards.txt'
standards = load_text_from_file(file_path)

# %%
#Imports needed for the code to work.
#Using a simple output parser and chat prompt template
from langchain_core.output_parsers import StrOutputParser
from langchain_core.prompts import ChatPromptTemplate
from langchain_core.runnables import RunnablePassthrough
from langchain_openai import ChatOpenAI, OpenAIEmbeddings


# This is the prompt used
template = """

You are a information retrieval AI. Format the retrieved information as a table or text


Use only the context for your answers, do not make up information

query: {query}

{context} 
"""

# Converts the prompt into a prompt template
prompt = ChatPromptTemplate.from_template(template)
#Using OpenAI model, by default gpt 3.5 Turbo
model = ChatOpenAI(api_key =api_key)

# Construction of the chain
chain = (
# The initial dictionary uses the retriever and user supplied query
    {"context":retriever,
     "query":RunnablePassthrough()}
# Feeds that context and query into the prompt then model & lastly 
# uses the ouput parser, do query for the data.
    |  prompt  | model | StrOutputParser()
 
)

# %%
# Example usage
result = chain.invoke({"query": "hi"})
print(result)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[29], line 2
#       1 # Example usage
# ----> 2 result = chain.invoke({"query": "hi"})
#       3 print(result)
#
# File c:\Users\Parsapu.Raj.INCOFORGETECH\EIA_Generation\.venv\lib\site-packages\langchain_core\runnables\base.py:3022, in RunnableSequence.invoke(self, input, config, **kwargs)
#    3020 context.run(_set_config_context, config)
#    3021 if i == 0:
# -> 3022     input = context.run(step.invoke, input, config, **kwargs)
#    3023 else:
#    3024     input = context.run(step.invoke, input, config)
#
# File c:\Users\Parsapu.Raj.INCOFORGETECH\EIA_Generation\.venv\lib\site-packages\langchain_core\runnables\base.py:3729, in RunnableParallel.invoke(self, input, config, **kwargs)
#    3724     with get_executor_for_config(config) as executor:
#    3725         futures = [
#    3726             executor.submit(_invoke_step, step, input, config, key)
#    3727             for key, step in steps.items()
#    3728         ]
# -> 3729         output = {key: future.result() for key, future in zip(steps, futures)}
#    3730 # finish the root run
#    3731 except BaseException as e:
#
# File c:\Users\Parsapu.Raj.INCOFORGETECH\EIA_Generation\.venv\lib\site-packages\langchain_core\runnables\base.py:3729, in <dictcomp>(.0)
#    3724     with get_executor_for_config(config) as executor:
#    3725         futures = [
#    3726             executor.submit(_invoke_step, step, input, config, key)
#    3727             for key, step in steps.items()
#    3728         ]
# -> 3729         output = {key: future.result() for key, future in zip(steps, futures)}
#    3730 # finish the root run
#    3731 except BaseException as e:
#
# File ~\AppData\Local\Programs\Python\Python310\lib\concurrent\futures\_base.py:438, in Future.result(self, timeout)
#     436     raise CancelledError()
#     437 elif self._state == FINISHED:
# --> 438     return self.__get_result()
#     440 self._condition.wait(timeout)
#     442 if self._state in [CANCELLED, CANCELLED_AND_NOTIFIED]:
#
# File ~\AppData\Local\Programs\Python\Python310\lib\concurrent\futures\_base.py:390, in Future.__get_result(self)
#     388 if self._exception:
#     389     try:
# --> 390         raise self._exception
#     391     finally:
#     392         # Break a reference cycle with the exception in self._exception
#     393         self = None
#
# File ~\AppData\Local\Programs\Python\Python310\lib\concurrent\futures\thread.py:52, in _WorkItem.run(self)
#      49     return
#      51 try:
# ---> 52     result = self.fn(*self.args, **self.kwargs)
#      53 except BaseException as exc:
#      54     self.future.set_exception(exc)
#
# File c:\Users\Parsapu.Raj.INCOFORGETECH\EIA_Generation\.venv\lib\site-packages\langchain_core\runnables\base.py:3713, in RunnableParallel.invoke.<locals>._invoke_step(step, input, config, key)
#    3711 context = copy_context()
#    3712 context.run(_set_config_context, child_config)
# -> 3713 return context.run(
#    3714     step.invoke,
#    3715     input,
#    3716     child_config,
#    3717 )
#
# File c:\Users\Parsapu.Raj.INCOFORGETECH\EIA_Generation\.venv\lib\site-packages\langchain_core\retrievers.py:259, in BaseRetriever.invoke(self, input, config, **kwargs)
#     257 _kwargs = kwargs if self._expects_other_args else {}
#     258 if self._new_arg_supported:
# --> 259     result = self._get_relevant_documents(
#     260         input, run_manager=run_manager, **_kwargs
#     261     )
#     262 else:
#     263     result = self._get_relevant_documents(input, **_kwargs)
#
# File c:\Users\Parsapu.Raj.INCOFORGETECH\EIA_Generation\.venv\lib\site-packages\langchain_core\vectorstores\base.py:1073, in VectorStoreRetriever._get_relevant_documents(self, query, run_manager, **kwargs)
#    1071 _kwargs = self.search_kwargs | kwargs
#    1072 if self.search_type == "similarity":
# -> 1073     docs = self.vectorstore.similarity_search(query, **_kwargs)
#    1074 elif self.search_type == "similarity_score_threshold":
#    1075     docs_and_similarities = (
#    1076         self.vectorstore.similarity_search_with_relevance_scores(
#    1077             query, **_kwargs
#    1078         )
#    1079     )
#
# File c:\Users\Parsapu.Raj.INCOFORGETECH\EIA_Generation\.venv\lib\site-packages\langchain_community\vectorstores\faiss.py:643, in FAISS.similarity_search(self, query, k, filter, fetch_k, **kwargs)
#     623 def similarity_search(
#     624     self,
#     625     query: str,
#    (...)
#     629     **kwargs: Any,
#     630 ) -> List[Document]:
#     631     """Return docs most similar to query.
#     632
#     633     Args:
#    (...)
#     641         List of Documents most similar to the query.
#     642     """
# --> 643     docs_and_scores = self.similarity_search_with_score(
#     644         query, k, filter=filter, fetch_k=fetch_k, **kwargs
#     645     )
#     646     return [doc for doc, _ in docs_and_scores]
#
# File c:\Users\Parsapu.Raj.INCOFORGETECH\EIA_Generation\.venv\lib\site-packages\langchain_community\vectorstores\faiss.py:515, in FAISS.similarity_search_with_score(self, query, k, filter, fetch_k, **kwargs)
#     491 def similarity_search_with_score(
#     492     self,
#     493     query: str,
#    (...)
#     497     **kwargs: Any,
#     498 ) -> List[Tuple[Document, float]]:
#     499     """Return docs most similar to query.
#     500
#     501     Args:
#    (...)
#     513         L2 distance in float. Lower score represents more similarity.
#     514     """
# --> 515     embedding = self._embed_query(query)
#     516     docs = self.similarity_search_with_score_by_vector(
#     517         embedding,
#     518         k,
#    (...)
#     521         **kwargs,
#     522     )
#     523     return docs
#
# File c:\Users\Parsapu.Raj.INCOFORGETECH\EIA_Generation\.venv\lib\site-packages\langchain_community\vectorstores\faiss.py:266, in FAISS._embed_query(self, text)
#     264 def _embed_query(self, text: str) -> List[float]:
#     265     if isinstance(self.embedding_function, Embeddings):
# --> 266         return self.embedding_function.embed_query(text)
#     267     else:
#     268         return self.embedding_function(text)
#
# File c:\Users\Parsapu.Raj.INCOFORGETECH\EIA_Generation\.venv\lib\site-packages\langchain_openai\embeddings\base.py:629, in OpenAIEmbeddings.embed_query(self, text)
#     620 def embed_query(self, text: str) -> List[float]:
#     621     """Call out to OpenAI's embedding endpoint for embedding query text.
#     622
#     623     Args:
#    (...)
#     627         Embedding for the text.
#     628     """
# --> 629     return self.embed_documents([text])[0]
#
# File c:\Users\Parsapu.Raj.INCOFORGETECH\EIA_Generation\.venv\lib\site-packages\langchain_openai\embeddings\base.py:588, in OpenAIEmbeddings.embed_documents(self, texts, chunk_size)
#     585 # NOTE: to keep things simple, we assume the list may contain texts longer
#     586 #       than the maximum context and use length-safe embedding function.
#     587 engine = cast(str, self.deployment)
# --> 588 return self._get_len_safe_embeddings(texts, engine=engine)
#
# File c:\Users\Parsapu.Raj.INCOFORGETECH\EIA_Generation\.venv\lib\site-packages\langchain_openai\embeddings\base.py:480, in OpenAIEmbeddings._get_len_safe_embeddings(self, texts, engine, chunk_size)
#     464 """
#     465 Generate length-safe embeddings for a list of texts.
#     466
#    (...)
#     477     List[List[float]]: A list of embeddings for each input text.
#     478 """
#     479 _chunk_size = chunk_size or self.chunk_size
# --> 480 _iter, tokens, indices = self._tokenize(texts, _chunk_size)
#     481 batched_embeddings: List[List[float]] = []
#     482 for i in _iter:
#
# File c:\Users\Parsapu.Raj.INCOFORGETECH\EIA_Generation\.venv\lib\site-packages\langchain_openai\embeddings\base.py:441, in OpenAIEmbeddings._tokenize(self, texts, chunk_size)
#     439     token = encoding.encode(text, **encoder_kwargs)
#     440 else:
# --> 441     token = encoding.encode_ordinary(text)
#     443 # Split tokens into chunks respecting the embedding_ctx_length
#     444 for j in range(0, len(token), self.embedding_ctx_length):
#
# File c:\Users\Parsapu.Raj.INCOFORGETECH\EIA_Generation\.venv\lib\site-packages\tiktoken\core.py:73, in Encoding.encode_ordinary(self, text)
#      64 """Encodes a string into tokens, ignoring special tokens.
#      65
#      66 This is equivalent to `encode(text, disallowed_special=())` (but slightly faster).
#    (...)
#      70 [31373, 995]
#      71 """
#      72 try:
# ---> 73     return self._core_bpe.encode_ordinary(text)
#      74 except UnicodeEncodeError:
#      75     # See comment in encode
#      76     text = text.encode("utf-16", "surrogatepass").decode("utf-16", "replace")
#
# TypeError: argument 'text': 'dict' object cannot be converted to 'PyString'
